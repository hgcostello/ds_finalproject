# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
import nibabel as nib

# %%
img = nib.load('ds107_sub001_highres.nii')

# %%
# data1 = np.asanyarray(img.dataobj)
data = img.get_fdata()

# (data == data1).all()

# %%
test = data[:,:,59]
plt.imshow(test)
plt.show()

# %%
for i in range(5):
    plt.subplot(5, 5,i + 1)
    plt.imshow(data[:,:,59 + i])
    plt.gcf().set_size_inches(10, 10)
plt.show()

# %%
# Out:
# True

# %%
# Out:
# True

# %%
# import skimage, os
# from skimage.morphology import ball, disk, dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing
# from skimage.measure import label,regionprops, perimeter
# from skimage.morphology import binary_dilation, binary_opening
# from skimage.filters import roberts, sobel
# from skimage import measure, feature
# from skimage.segmentation import clear_border
# from skimage import data
# from scipy import ndimage as ndi
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d.art3d import Poly3DCollection
# import scipy.misc
# import numpy as np
# from glob import glob
# from skimage.io import imread
# BASE_IMG_PATH=os.path.join('..','input')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-730843005df7> in <module>
# ----> 1 import skimage, os
#       2 from skimage.morphology import ball, disk, dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing
#       3 from skimage.measure import label,regionprops, perimeter
#       4 from skimage.morphology import binary_dilation, binary_opening
#       5 from skimage.filters import roberts, sobel
#
# ModuleNotFoundError: No module named 'skimage'

# %%
glob(os.path.join(BASE_IMG_PATH,'3d_images','*'))
